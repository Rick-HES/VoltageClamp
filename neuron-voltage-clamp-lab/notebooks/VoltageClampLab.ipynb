# %% [markdown]
# # NEURON Voltage Clamp Lab
#
# Use the controls to run a voltage-clamp simulation on a single-compartment Hodgkin–Huxley model.
#
# **Tip:** If you're opening this via Binder, wait for the environment to finish loading, then run the cell below.

# %%
from src.lab import build_ui
build_ui()
